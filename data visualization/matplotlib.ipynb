# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y =x** 2

# %%
plt.plot(x,y)
plt.title("Hello title")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.subplot(2,2,1)
plt.plot(x,y **2)
plt.subplot(2,2,2)
plt.plot(x **2 ,y)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.savefig("basic plot")

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19b2303a7b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19b2303aa50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19b2303a660>],
#  'medians': [<matplotlib.lines.Line2D at 0x19b2303acf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19b2303ae40>],
#  'means': []}

# %%
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1., 2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)
