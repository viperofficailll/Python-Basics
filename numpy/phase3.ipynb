# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure : [restaurant_id , 2021 ,2022 ,2023 ,2024]


sales_data = np.array(
    [
        [1, 150000, 180000, 220000, 200000],  # Paradise biryani
        [2, 120000, 140000, 160000, 190000],  # Beijing bites
        [3, 200000, 230000, 260000, 240000],  # pizza hub
        [4, 180000, 210000, 240000, 270000],  # Burger point
        [5, 160000, 185000, 205000, 230000],  # chill point
    ]
)
print("====Zomato sales analysis==== \n")
print("sales data shape ", sales_data.shape)
print(" \n sample data for first 3 restaurant \n", sales_data[0:3])
# Out:
# ====Zomato sales analysis====
#
# sales data shape  (5, 5)
#
#  sample data for first 3 restaurant
#  [[     1 150000 180000 220000 200000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 240000]]

# %%
# Total sales per year
yearly_total = np.sum(sales_data[:, 1:], axis=0)
print(yearly_total)
# Out:
# [ 810000  945000 1085000 1130000]

# %%
# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)
print("Min sales  per restaurant \n", min_sales)
# Out:
# Min sales  per restaurant
#  [150000 120000 200000 180000 160000]

# %%
# Maximum sales in a year by a restaurant
max_sales = np.max(sales_data[:, 1:], axis=0)
print("max sales in a  year \n", max_sales)
# Out:
# max sales in a  year
#  [200000 230000 260000 270000]

# %%
# Average sales per restaurant
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print("Average sales per year", avg_sales)
# Out:
# Average sales per year [187500. 152500. 232500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(cumsum)
plt.figure(figsize=(10, 5))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumulative sales")
plt.xlabel("years")
plt.ylabel("amount")
plt.grid()
plt.show()
# Out:
# [[150000 330000 550000 750000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 930000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
years = [2021, 2022, 2023, 2024]
restaurant_names = [
    "Paradise Biryani",
    "Beijing Bites",
    "Pizza Hub",
    "Burger Point",
    "Chill Point",
]

plt.figure(figsize=(10,6))
for i in range (len(sales_data)):
    plt.plot(years,sales_data[i,1:] ,marker ="o" ,label =restaurant_names[i])
plt.title('Restaurant sales per year')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.grid(True)
plt.legend()
plt.show()

# %%
monthly_average = sales_data[:, 1:] / 12

print(monthly_average)

years = [2021, 2022, 2023, 2024]

restaurants = [
    "Paradise Biryani",
    "Beijing Bites",
    "Pizza Hub",
    "Burger Point",
    "Chill Point"
]

plt.figure(figsize=(10, 6))

for i in range(len(monthly_average)):
    plt.plot(
        years,
        monthly_average[i],
        marker="o",
        linewidth=2,
        label=restaurants[i]
    )

plt.title("Average Monthly Sales by Restaurant")
plt.xlabel("Year")
plt.ylabel("Average Monthly Sales")
plt.xticks(years)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [[12500.         15000.         18333.33333333 16666.66666667]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 20000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
